# %%
#WHILE LOOP

# %%
number=0
while number <5:
    print(number)
    number= number + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#break statement
number=0
while number <5:
    print(number)
    if number==3:
     break
    number= number + 1
# Out:
# 0
# 1
# 2
# 3

# %%
number=0
while number <5:
    print(number)
    if number== 7:
     break
    number= number + 1
else:
    print('not applicable')
# Out:
# 0
# 1
# 2
# 3
# 4
# not applicable

# %%
number=0
while number <5:
    print(number)
    if number== 3:
     continue
    number= number + 1
else:
    print('not applicable')
# Out:
# 0
# 1
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
number=0 

while number <5:
   number= number +1
   if number == 3:
     continue
   print(number)
else:
    print('not applicable')
# Out:
# 1
# 2
# 4
# 5
# not applicable

# %%
number=5

while number <15:
 number=number+2
 if number==9:
  continue
 print(number)
else:
 print('no')
# Out:
# 7
# 11
# 13
# 15
# no
